# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.

# %% [markdown]
# Poverty and its affects on education have always been a major issue in the United States. This project aims to explore if states that have the highest percentage of children under 18 living in poverty have any correlation between the reported ACT scores of those states between 2017-2019.  It will also give recommendations on how to increase overall SAT composite scores.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# "The poverty rate in U.S. is close to 12%, meaning 1 in 8 Americans live at or below the poverty level.
# 1 in 6 children in the U.S. are living in poverty
# The poverty rate for single-mother households is 31%, meaning almost 1 in 3 single mothers live in poverty.
# 11 million children, or about 1 in 9 of all children in the U.S., live at 50 percent below the federal poverty line.
# 37% of children raised in poverty do not finish high school." ([*source*](https://www.childfund.org/Content/NewsDetail/2147489206/))

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# For this project, we will use the following datasets:
#
# act_2017.csv: 2017 ACT Scores by State
#
# act_2018.csv: 2018 ACT Scores by State
#
# act_2019.csv: 2019 ACT Scores by State
#
# census_poverty_2017_to_2019.csv: 2017 - 2019 Poverty Statistics by State ([*source*](https://www.census.gov/data-tools/demo/saipe/#/?map_geoSelector=aa_c))
#
# Dictionaries created:
#
# region_dict : U.S. Census Regions with the state as a key and the region as a value. Created from ([*source*](https://www2.census.gov/geo/pdfs/maps-data/maps/reference/us_regdiv.pdf))
#
# election_2020_dict : 2020 Presidential Election results with the state as a key and value set to whether it went "Red" or "Blue" in the election. Created for ([*source*](https://www.archives.gov/electoral-college/2020))

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# "As of January 1, 2021, there were five states without minimum wage laws, two states with minimum wages below the federal minimum, 14 states with minimum wages at the federal level, and 29 states, plus Washington, DC, with minimum wages above the federal level, according to the Department of Labor. This is a significant change from 1980, when only two states, plus Washington, DC, had minimum wages above the federal level.
#
# State minimum wages in 2021 range from \\$5.15 per hour in Georgia and Wyoming to \\$15 per hour in Washington, DC." ([*source*](https://usafacts.org/articles/minimum-wage-america-how-many-people-are-earning-725-hour/?utm_source=google&utm_medium=cpc&utm_campaign=ND-Economy&gclid=CjwKCAjwhOyJBhA4EiwAEcJdcUqIuVa1resZvhGasOFR6eH3lAeYrXiWGz0jgh_fc6F6QBrPfwhcqRoCIDIQAvD_BwE))
#
# Some states require the ACT to be taken, so average composite scores may be a better indicator of success than participation rates. ([*source*](https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice))

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code to calculate mean

def calculate_mean(list_nums):
    return sum(list_nums) / len(list_nums)

test_list = [1,2,3,4,5]

calculate_mean(test_list)
# Out:
# 3.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.
#
# Step 1: Find the mean.
#
# Step 2: For each data point, find the square of its distance to the mean.
#
# Step 3: Sum the values from Step 2.
#
# Step 4: Divide by the number of data points.
#
# Step 5: Take the square root. ([*source*](https://www.khanacademy.org/math/statistics-probability/summarizing-quantitative-data/variance-standard-deviation-population/a/calculating-standard-deviation-step-by-step))

# %%
# Code to calculate standard deviation

def calculate_stdev(list_nums):
    mean = calculate_mean(list_nums)
    distance_squared = []
    for num in list_nums:
        distance_squared.append((num - mean)**2)
    avg_distance_squared = calculate_mean(distance_squared)
    std_dev = avg_distance_squared ** .5
    return std_dev

calculate_stdev(test_list)
# Out:
# 1.4142135623730951

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code to make a string percentage into a float percentage

def pct_str_to_pct_dec(pct_str):
    strip = pct_str.replace("%","")
    return float(strip)/100

pct_str_to_pct_dec("30.5%")
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Import pandas, numpy, matplotlib, and seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# act_2017.csv

# %%
#read in 2017 ACT data and check it
act_2017 = pd.read_csv('../data/act_2017.csv')
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act_2017.isnull().sum() #check for nulls
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
act_2017.describe(include='all')
# Out:
#             State Participation    English       Math    Reading    Science  \
# count          52            52  52.000000  52.000000  52.000000  52.000000
# unique         52            28        NaN        NaN        NaN        NaN
# top     Louisiana          100%        NaN        NaN        NaN        NaN
# freq            1            17        NaN        NaN        NaN        NaN
# mean          NaN           NaN  20.919231  21.173077  22.001923  21.040385
# std           NaN           NaN   2.332132   1.963602   2.048672   3.151113
# min           NaN           NaN  16.300000  18.000000  18.100000   2.300000
# 25%           NaN           NaN  19.000000  19.400000  20.475000  19.900000
# 50%           NaN           NaN  20.550000  20.900000  21.700000  21.150000
# 75%           NaN           NaN  23.300000  23.100000  24.125000  22.525000
# max           NaN           NaN  25.500000  25.300000  26.000000  24.900000
#
#        Composite
# count         52
# unique        38
# ...

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
act_2017['Composite'] = [value.replace("x", "") for value in act_2017['Composite']] #replace the x type

# %%
act_2017['Composite'] = [float(value) for value in act_2017['Composite']] #convert composite scores to floats

# %%
act_2017['Participation'] = [pct_str_to_pct_dec(value) for value in act_2017['Participation']] #make % strs into % floats

# %%
act_2017 = act_2017[act_2017['State'] != 'National'] ##Drop National Row

# %%
act_2017 = act_2017.drop(['English', 'Math', 'Reading', 'Science'], axis=1) #drop extra columns

# %%
act_2017['Year'] = 2017 #add date year as column

# %%
act_2017['Year'] = pd.to_datetime(act_2017['Year'], format="%Y") #convert it to datetime

# %%
act_2017.columns = act_2017.columns.str.lower() #lowercase column names

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          51 non-null     object
#  1   participation  51 non-null     float64
#  2   composite      51 non-null     float64
#  3   year           51 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 2.0+ KB

# %%
act_2017.head()
# Out:
#         state  participation  composite       year
# 1     Alabama           1.00       19.2 2017-01-01
# 2      Alaska           0.65       19.8 2017-01-01
# 3     Arizona           0.62       19.7 2017-01-01
# 4    Arkansas           1.00       19.4 2017-01-01
# 5  California           0.31       22.8 2017-01-01

# %%
act_2017.to_csv('../data/clean_act_2017.csv', index=False) #export as csv

# %% [markdown]
# act_2018.csv

# %%
act_2018 = pd.read_csv('../data/act_2018.csv')
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
act_2018.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
act_2018.describe(include='all')
# Out:
#         State Participation  Composite
# count      52            52  52.000000
# unique     51            29        NaN
# top     Maine          100%        NaN
# freq        2            17        NaN
# mean      NaN           NaN  21.544231
# std       NaN           NaN   2.119417
# min       NaN           NaN  17.700000
# 25%       NaN           NaN  19.975000
# 50%       NaN           NaN  21.300000
# 75%       NaN           NaN  23.725000
# max       NaN           NaN  25.600000

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
act_2018['State'] = [value.replace("columbia", "Columbia") for value in act_2018['State']] #capitalize Colombia

# %%
act_2018['Participation'] = [pct_str_to_pct_dec(value) for value in act_2018['Participation']] #convert % strs to % floats

# %%
act_2018 = act_2018[act_2018['State'] != 'National'] ##Drop National Row

# %%
act_2018['Year'] = 2018 #add year as column

# %%
act_2018['Year'] = pd.to_datetime(act_2018['Year'], format="%Y") #convert to datetime

# %%
act_2018.columns = act_2018.columns.str.lower() #lowercase the column names

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          52 non-null     object
#  1   participation  52 non-null     float64
#  2   composite      52 non-null     float64
#  3   year           52 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 2.0+ KB

# %%
act_2018.head()
# Out:
#         state  participation  composite       year
# 0     Alabama           1.00       19.1 2018-01-01
# 1      Alaska           0.33       20.8 2018-01-01
# 2     Arizona           0.66       19.2 2018-01-01
# 3    Arkansas           1.00       19.4 2018-01-01
# 4  California           0.27       22.7 2018-01-01

# %%
act_2018 = act_2018.drop(index = 19) #drop the duplicate Maine row

# %%
act_2018.to_csv('../data/clean_act_2018.csv', index=False) #export as csv

# %% [markdown]
# act_2019.csv

# %%
act_2019 = pd.read_csv('../data/act_2019.csv')
act_2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
act_2019.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
act_2019.describe(include='all')
# Out:
#             State Participation  Composite
# count          52            52  52.000000
# unique         52            35        NaN
# top     Louisiana          100%        NaN
# freq            1            15        NaN
# mean          NaN           NaN  21.450000
# std           NaN           NaN   2.175487
# min           NaN           NaN  17.900000
# 25%           NaN           NaN  19.800000
# 50%           NaN           NaN  20.950000
# 75%           NaN           NaN  23.650000
# max           NaN           NaN  25.500000

# %%
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
act_2019 = act_2019[act_2019['State'] != 'National'] ##Drop National Row

# %%
act_2019['Participation'] = [pct_str_to_pct_dec(value) for value in act_2019['Participation']] #convert % strs to % floats

# %%
act_2019['Year'] = 2019 #add the year as column

# %%
act_2019['Year'] = pd.to_datetime(act_2019['Year'], format="%Y") #convert to datetime

# %%
act_2019.columns = act_2019.columns.str.lower() #lowercase column names

# %%
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          51 non-null     object
#  1   participation  51 non-null     float64
#  2   composite      51 non-null     float64
#  3   year           51 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 2.0+ KB

# %%
act_2019.head()
# Out:
#         state  participation  composite       year
# 0     Alabama           1.00       18.9 2019-01-01
# 1      Alaska           0.38       20.1 2019-01-01
# 2     Arizona           0.73       19.0 2019-01-01
# 3    Arkansas           1.00       19.3 2019-01-01
# 4  California           0.23       22.6 2019-01-01

# %%
act_2019.to_csv('../data/clean_act_2019.csv', index=False) #export as csv

# %%
act_concat = pd.concat([act_2017, act_2018, act_2019]) #join all years into one dataset

# %%
#check the data to make sure join worked
pd.pivot_table(act_concat, index='state', columns='year')
# Out:
#                       composite                       participation  \
# year                 2017-01-01 2018-01-01 2019-01-01    2017-01-01
# state
# Alabama                    19.2       19.1       18.9          1.00
# Alaska                     19.8       20.8       20.1          0.65
# Arizona                    19.7       19.2       19.0          0.62
# Arkansas                   19.4       19.4       19.3          1.00
# California                 22.8       22.7       22.6          0.31
# Colorado                   20.8       23.9       23.8          1.00
# Connecticut                25.2       25.6       25.5          0.31
# Delaware                   24.1       23.8       24.1          0.18
# District of Columbia       24.2       23.6       23.5          0.32
# Florida                    19.8       19.9       20.1          0.73
# Georgia                    21.4       21.4       21.4          0.55
# Hawaii                     19.0       18.9       19.0          0.90
# ...

# %% [markdown]
# census_poverty_2017_to_2019.csv:

# %%
pov_census = pd.read_csv('../data/census_poverty_2017_to_2019.csv') #import the entire US census poverty info 2017-2019

# %%
pov_census = pov_census.loc[:,['Year', 'State / County Name', "Under Age 18 in Poverty Percent"]] #drop extra rows

# %%
pov_census = pov_census[pov_census['State / County Name'].isin(act_concat['state'].unique())] #keep only state rows

# %%
pov_census.rename(columns={'State / County Name': 'State', 'Under Age 18 in Poverty Percent': 'child_pov_rate'},
                  inplace=True) #rename the columns to match ACT dataset

# %%
pov_census['Year'] = pd.to_datetime(pov_census['Year'], format="%Y") #convert yet to datetime

# %%
pov_census.columns = pov_census.columns.str.lower() #lowercase the column names

# %%
pov_census.to_csv('../data/clean_census_poverty_2017_to_2019.csv', index=False) #export clean census dataset

# %%
#merge the ACT info and US census povert data sets on state and year
merge_act_census = pd.merge(act_concat, pov_census, how='left', left_on=['state','year'], right_on=['state', 'year'])

# %%
merge_act_census['child_pov_rate'] =  merge_act_census['child_pov_rate'] / 100 #convert percentages to rates

# %%
merge_act_census #check merge
# Out:
#              state  participation  composite       year  child_pov_rate
# 0          Alabama           1.00       19.2 2017-01-01           0.244
# 1           Alaska           0.65       19.8 2017-01-01           0.145
# 2          Arizona           0.62       19.7 2017-01-01           0.210
# 3         Arkansas           1.00       19.4 2017-01-01           0.225
# 4       California           0.31       22.8 2017-01-01           0.181
# ..             ...            ...        ...        ...             ...
# 148       Virginia           0.21       24.0 2019-01-01           0.133
# 149     Washington           0.24       22.1 2019-01-01           0.120
# 150  West Virginia           0.49       20.8 2019-01-01           0.208
# 151      Wisconsin           1.00       20.3 2019-01-01           0.135
# 152        Wyoming           1.00       19.8 2019-01-01           0.117
#
# [153 rows x 5 columns]

# %%
#create a dictionary where states are keys and their US census region is the value
region_dict = {'Alabama' : 'South',
               'Alaska' : 'West',
               'Arizona' : 'West',
               'Arkansas' : 'South',
               'California' : 'West',
               'Colorado' : 'West',
               'Connecticut' : 'Northeast',
               'Delaware' : 'South',
               'District of Columbia' : 'South',
               'Florida' : 'South',
               'Georgia' : 'South',
               'Hawaii' : 'West',
               'Idaho' : 'West',
               'Illinois' : 'Midwest',
               'Indiana' : 'Midwest',
               'Iowa' : 'Midwest',
               'Kansas' : 'Midwest',
               'Kentucky' : 'South',
               'Louisiana' : 'South',
               'Maine' : 'Northeast',
               'Maryland' : 'South',
               'Massachusetts' : 'Northeast',
               'Michigan' : 'Midwest',
               'Minnesota' : 'Midwest',
               'Mississippi' : 'South',
               'Missouri' : 'Midwest',
               'Montana' : 'West',
               'Nebraska' : 'Midwest',
               'Nevada' : 'West',
               'New Hampshire' : 'Northeast',
               'New Jersey' : 'Northeast',
               'New Mexico' : 'West',
               'New York' : 'Northeast',
               'North Carolina' : 'South',
               'North Dakota' : 'Midwest',
               'Ohio' : 'Midwest',
               'Oklahoma' : 'South',
               'Oregon' : 'West',
               'Pennsylvania' : 'Northeast',
               'Rhode Island' : 'Northeast',
               'South Carolina' : 'South',
               'South Dakota' : 'Midwest',
               'Tennessee' : 'South',
               'Texas' : 'South',
               'Utah' : 'West',
               'Vermont' : 'Northeast',
               'Virginia' : 'South',
               'Washington' : 'West',
               'West Virginia' : 'South',
               'Wisconsin' : 'Midwest',
               'Wyoming': 'West'}

# %%
#create function to get region based on state
def get_region(state):
    return region_dict[state]

# %%
#get regions and add it as new column
merge_act_census['region'] = [get_region(value) for value in merge_act_census['state']]

# %%
#create a dictionary where states are keys and their 2020 election results are values
election_2020_dict = {'Alabama' : 'Red',
               'Alaska' : 'Red',
               'Arizona' : 'Blue',
               'Arkansas' : 'Red',
               'California' : 'Blue',
               'Colorado' : 'Blue',
               'Connecticut' : 'Blue',
               'Delaware' : 'Blue',
               'District of Columbia' : 'Blue',
               'Florida' : 'Red',
               'Georgia' : 'Blue',
               'Hawaii' : 'Blue',
               'Idaho' : 'Red',
               'Illinois' : 'Blue',
               'Indiana' : 'Red',
               'Iowa' : 'Red',
               'Kansas' : 'Red',
               'Kentucky' : 'Red',
               'Louisiana' : 'Red',
               'Maine' : 'Blue',
               'Maryland' : 'Blue',
               'Massachusetts' : 'Blue',
               'Michigan' : 'Blue',
               'Minnesota' : 'Blue',
               'Mississippi' : 'Red',
               'Missouri' : 'Red',
               'Montana' : 'Red',
               'Nebraska' : 'Red',
               'Nevada' : 'Blue',
               'New Hampshire' : 'Blue',
               'New Jersey' : 'Blue',
               'New Mexico' : 'Blue',
               'New York' : 'Blue',
               'North Carolina' : 'Red',
               'North Dakota' : 'Red',
               'Ohio' : 'Red',
               'Oklahoma' : 'Red',
               'Oregon' : 'Blue',
               'Pennsylvania' : 'Blue',
               'Rhode Island' : 'Blue',
               'South Carolina' : 'Red',
               'South Dakota' : 'Red',
               'Tennessee' : 'Red',
               'Texas' : 'Red',
               'Utah' : 'Red',
               'Vermont' : 'Blue',
               'Virginia' : 'Blue',
               'Washington' : 'Blue',
               'West Virginia' : 'Red',
               'Wisconsin' : 'Blue',
               'Wyoming': 'Red'}

# %%
#create function to get election results
def get_election_rslt(state):
    return election_2020_dict[state]

# %%
#create new column for 2020 election results
merge_act_census['election_2020'] = [get_election_rslt(value) for value in merge_act_census['state']]

# %%
merge_act_census.to_csv('../data/project_1_dataset.csv', index=False) #export project 1 dataset

# %%
merge_act_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 0 to 152
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   state           153 non-null    object
#  1   participation   153 non-null    float64
#  2   composite       153 non-null    float64
#  3   year            153 non-null    datetime64[ns]
#  4   child_pov_rate  153 non-null    float64
#  5   region          153 non-null    object
#  6   election_2020   153 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 9.6+ KB

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|*object*|ACT 2017-2019/U.S. Census 2017-2019|The U.S. state to which the data applies.|
# |participation|*float*|ACT 2017-2019|The percentage of students who participated in the ACT. Participation may be mandated by state.|
# |composite|*float*|ACT 2017-2019|The average composite score across all four areas of the ACT.|
# |year|*datetime*|ACT 2017-2019/U.S. Census 2017-2019|The year to which the data applies.|
# |child_pov_rate|*float*|U.S. Census 2017-2019|Percentage of minors under age 18 living in poverty. For more info on how the U.S. Census Bureau determines the poverty level, click [here](https://www.census.gov/topics/income-poverty/poverty/guidance/poverty-measures.html)|
# |region|*object*|U.S. Census Regions 2010|Which region of the U.S. the state resides in. For more info on how the U.S. Census Bureau breaks up the census regions, click [here](https://www2.census.gov/geo/pdfs/maps-data/maps/reference/us_regdiv.pdf)|
# |election_2020|*object*|National Archives 2020 Electoral College Results|Determines whether the majority of the state's electoral college votes went toward the Republican candidate (red) or the Democratic candidate (blue) in the 2020 presidential election. For more info, click [here](https://www.archives.gov/electoral-college/2020)|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.

# %%
pd.pivot_table(merge_act_census, index='state', columns='year').describe()
# Out:
#       child_pov_rate                        composite                        \
# year      2017-01-01 2018-01-01 2019-01-01 2017-01-01 2018-01-01 2019-01-01
# count      51.000000  51.000000  51.000000  51.000000  51.000000  51.000000
# mean        0.175588   0.172510   0.160294  21.519608  21.496078  21.464706
# std         0.046704   0.046203   0.043179   2.020695   2.111583   2.194523
# min         0.100000   0.097000   0.081000  17.800000  17.700000  17.900000
# 25%         0.137500   0.135000   0.125000  19.800000  19.950000  19.800000
# 50%         0.170000   0.167000   0.156000  21.400000  21.300000  21.100000
# 75%         0.210000   0.207000   0.192500  23.600000  23.650000  23.700000
# max         0.277000   0.282000   0.276000  25.500000  25.600000  25.500000
#
#       participation
# year     2017-01-01 2018-01-01 2019-01-01
# count     51.000000  51.000000  51.000000
# mean       0.652549   0.617255   0.586667
# std        0.321408   0.340371   0.345159
# ...

# %%
merge_act_census.describe()
# Out:
#        participation   composite  child_pov_rate
# count     153.000000  153.000000      153.000000
# mean        0.618824   21.493464        0.169464
# std         0.334678    2.096321        0.045573
# min         0.060000   17.700000        0.081000
# 25%         0.290000   19.800000        0.132000
# 50%         0.660000   21.300000        0.165000
# 75%         1.000000   23.600000        0.202000
# max         1.000000   25.600000        0.282000

# %% [markdown]
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#create dictionary with numeric column name as keys and the columns std dev as the key
sd = {column_name: calculate_stdev(merge_act_census[column_name]) \
    for column_name in merge_act_census.columns \
    if merge_act_census[column_name].dtype == "float64"}
sd
# Out:
# {'participation': 0.33358214474024833,
#  'composite': 2.089459172687678,
#  'child_pov_rate': 0.04542407673225355}

# %% [markdown]
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):

# %% [markdown]
#          - Which states have the highest and lowest participation rates for the ACT in 2017, 2018, & 2019?

# %% [markdown]
# # Highest Participation Rates

# %% [markdown]
# # 2017

# %%
merge_act_census[merge_act_census['year']== '2017-01-01'].sort_values(by = 'participation', ascending= False).head(10)
# Out:
#              state  participation  composite       year  child_pov_rate  \
# 0          Alabama            1.0       19.2 2017-01-01           0.244
# 17        Kentucky            1.0       20.0 2017-01-01           0.221
# 49       Wisconsin            1.0       20.5 2017-01-01           0.146
# 44            Utah            1.0       20.3 2017-01-01           0.106
# 42       Tennessee            1.0       19.8 2017-01-01           0.211
# 40  South Carolina            1.0       18.7 2017-01-01           0.223
# 36        Oklahoma            1.0       19.4 2017-01-01           0.213
# 33  North Carolina            1.0       19.1 2017-01-01           0.210
# 28          Nevada            1.0       17.8 2017-01-01           0.192
# 26         Montana            1.0       20.3 2017-01-01           0.159
#
#      region election_2020
# 0     South           Red
# 17    South           Red
# 49  Midwest          Blue
# 44     West           Red
# 42    South           Red
# ...

# %% [markdown]
# # 2018

# %%
merge_act_census[merge_act_census['year']== '2018-01-01'].sort_values(by = 'participation', ascending= False).head(10)
# Out:
#               state  participation  composite       year  child_pov_rate  \
# 51          Alabama            1.0       19.1 2018-01-01           0.239
# 68         Kentucky            1.0       20.2 2018-01-01           0.223
# 100       Wisconsin            1.0       20.5 2018-01-01           0.141
# 95             Utah            1.0       20.4 2018-01-01           0.097
# 93        Tennessee            1.0       19.6 2018-01-01           0.218
# 91   South Carolina            1.0       18.3 2018-01-01           0.221
# 87         Oklahoma            1.0       19.3 2018-01-01           0.214
# 86             Ohio            1.0       20.3 2018-01-01           0.192
# 84   North Carolina            1.0       19.1 2018-01-01           0.202
# 79           Nevada            1.0       17.7 2018-01-01           0.184
#
#       region election_2020
# 51     South           Red
# 68     South           Red
# 100  Midwest          Blue
# 95      West           Red
# ...

# %% [markdown]
# # 2019

# %%
merge_act_census[merge_act_census['year']== '2019-01-01'].sort_values(by = 'participation', ascending= False).head(10)
# Out:
#               state  participation  composite       year  child_pov_rate  \
# 102         Alabama            1.0       18.9 2019-01-01           0.219
# 119        Kentucky            1.0       19.8 2019-01-01           0.209
# 151       Wisconsin            1.0       20.3 2019-01-01           0.135
# 146            Utah            1.0       20.3 2019-01-01           0.096
# 144       Tennessee            1.0       19.4 2019-01-01           0.194
# 138        Oklahoma            1.0       18.9 2019-01-01           0.197
# 137            Ohio            1.0       20.0 2019-01-01           0.181
# 135  North Carolina            1.0       19.0 2019-01-01           0.193
# 130          Nevada            1.0       17.9 2019-01-01           0.176
# 129        Nebraska            1.0       20.0 2019-01-01           0.115
#
#       region election_2020
# 102    South           Red
# 119    South           Red
# 151  Midwest          Blue
# 146     West           Red
# ...

# %% [markdown]
# The majority of these states require ACT testing for all students.  Top 5 remained the same for all three years.

# %% [markdown]
# # Lowest Participation Rates

# %% [markdown]
# # 2017

# %%
merge_act_census[merge_act_census['year']== '2017-01-01'].sort_values(by = 'participation').head(10)
# Out:
#             state  participation  composite       year  child_pov_rate  \
# 19          Maine           0.08       24.3 2017-01-01           0.142
# 29  New Hampshire           0.18       25.5 2017-01-01           0.100
# 7        Delaware           0.18       24.1 2017-01-01           0.177
# 39   Rhode Island           0.21       24.0 2017-01-01           0.182
# 38   Pennsylvania           0.23       23.7 2017-01-01           0.169
# 20       Maryland           0.28       23.6 2017-01-01           0.124
# 45        Vermont           0.29       23.6 2017-01-01           0.128
# 21  Massachusetts           0.29       25.4 2017-01-01           0.135
# 22       Michigan           0.29       24.1 2017-01-01           0.196
# 46       Virginia           0.29       23.8 2017-01-01           0.140
#
#        region election_2020
# 19  Northeast          Blue
# 29  Northeast          Blue
# 7       South          Blue
# 39  Northeast          Blue
# 38  Northeast          Blue
# ...

# %% [markdown]
# # 2018

# %%
merge_act_census[merge_act_census['year']== '2018-01-01'].sort_values(by = 'participation').head(10)
# Out:
#             state  participation  composite       year  child_pov_rate  \
# 70          Maine           0.07       24.0 2018-01-01           0.148
# 90   Rhode Island           0.15       24.2 2018-01-01           0.180
# 80  New Hampshire           0.16       25.1 2018-01-01           0.101
# 58       Delaware           0.17       23.8 2018-01-01           0.176
# 89   Pennsylvania           0.20       23.5 2018-01-01           0.167
# 73       Michigan           0.22       24.2 2018-01-01           0.193
# 98     Washington           0.24       22.2 2018-01-01           0.126
# 96        Vermont           0.24       24.1 2018-01-01           0.122
# 97       Virginia           0.24       23.9 2018-01-01           0.138
# 72  Massachusetts           0.25       25.5 2018-01-01           0.124
#
#        region election_2020
# 70  Northeast          Blue
# 90  Northeast          Blue
# 80  Northeast          Blue
# 58      South          Blue
# 89  Northeast          Blue
# ...

# %% [markdown]
# # 2019

# %%
merge_act_census[merge_act_census['year']== '2019-01-01'].sort_values(by = 'participation').head(10)
# Out:
#              state  participation  composite       year  child_pov_rate  \
# 121          Maine           0.06       24.3 2019-01-01           0.138
# 141   Rhode Island           0.12       24.7 2019-01-01           0.165
# 109       Delaware           0.13       24.1 2019-01-01           0.163
# 131  New Hampshire           0.14       25.0 2019-01-01           0.081
# 140   Pennsylvania           0.17       23.6 2019-01-01           0.165
# 124       Michigan           0.19       24.4 2019-01-01           0.175
# 147        Vermont           0.20       24.1 2019-01-01           0.108
# 148       Virginia           0.21       24.0 2019-01-01           0.133
# 123  Massachusetts           0.21       25.5 2019-01-01           0.120
# 134       New York           0.22       24.5 2019-01-01           0.182
#
#         region election_2020
# 121  Northeast          Blue
# 141  Northeast          Blue
# 109      South          Blue
# 131  Northeast          Blue
# ...

# %% [markdown]
# These are the smallest states in the country that do not require ACT participation.  It's also interesting to note the states with the least participation in the ACT have less minors living in poverty than the states with the highest particiption rates.  Our next analysis should help us see if the performance on the ACT shows the same link.

# %% [markdown]
#         - Which states have the highest and lowest mean total/composite scores for the ACT in 2017, 2018, & 2019?

# %% [markdown]
# # Highest Mean Composite Scores

# %% [markdown]
# # 2017

# %%
merge_act_census[merge_act_census['year']== '2017-01-01'].sort_values(by = 'composite', ascending=False).head(10)
# Out:
#                    state  participation  composite       year  child_pov_rate  \
# 29         New Hampshire           0.18       25.5 2017-01-01           0.100
# 21         Massachusetts           0.29       25.4 2017-01-01           0.135
# 6            Connecticut           0.31       25.2 2017-01-01           0.130
# 19                 Maine           0.08       24.3 2017-01-01           0.142
# 8   District of Columbia           0.32       24.2 2017-01-01           0.262
# 32              New York           0.31       24.2 2017-01-01           0.199
# 22              Michigan           0.29       24.1 2017-01-01           0.196
# 7               Delaware           0.18       24.1 2017-01-01           0.177
# 39          Rhode Island           0.21       24.0 2017-01-01           0.182
# 30            New Jersey           0.34       23.9 2017-01-01           0.138
#
#        region election_2020
# 29  Northeast          Blue
# 21  Northeast          Blue
# ...

# %% [markdown]
# # 2018

# %%
merge_act_census[merge_act_census['year']== '2018-01-01'].sort_values(by = 'composite', ascending=False).head(10)
# Out:
#             state  participation  composite       year  child_pov_rate  \
# 57    Connecticut           0.26       25.6 2018-01-01           0.138
# 72  Massachusetts           0.25       25.5 2018-01-01           0.124
# 80  New Hampshire           0.16       25.1 2018-01-01           0.101
# 83       New York           0.27       24.5 2018-01-01           0.188
# 73       Michigan           0.22       24.2 2018-01-01           0.193
# 90   Rhode Island           0.15       24.2 2018-01-01           0.180
# 96        Vermont           0.24       24.1 2018-01-01           0.122
# 70          Maine           0.07       24.0 2018-01-01           0.148
# 64       Illinois           0.43       23.9 2018-01-01           0.162
# 56       Colorado           0.30       23.9 2018-01-01           0.121
#
#        region election_2020
# 57  Northeast          Blue
# 72  Northeast          Blue
# 80  Northeast          Blue
# 83  Northeast          Blue
# 73    Midwest          Blue
# ...

# %% [markdown]
# # 2019

# %%
merge_act_census[merge_act_census['year']== '2019-01-01'].sort_values(by = 'composite', ascending=False).head(10)
# Out:
#              state  participation  composite       year  child_pov_rate  \
# 123  Massachusetts           0.21       25.5 2019-01-01           0.120
# 108    Connecticut           0.22       25.5 2019-01-01           0.135
# 131  New Hampshire           0.14       25.0 2019-01-01           0.081
# 141   Rhode Island           0.12       24.7 2019-01-01           0.165
# 134       New York           0.22       24.5 2019-01-01           0.182
# 124       Michigan           0.19       24.4 2019-01-01           0.175
# 121          Maine           0.06       24.3 2019-01-01           0.138
# 115       Illinois           0.35       24.3 2019-01-01           0.156
# 132     New Jersey           0.25       24.2 2019-01-01           0.122
# 147        Vermont           0.20       24.1 2019-01-01           0.108
#
#         region election_2020
# 123  Northeast          Blue
# 108  Northeast          Blue
# 131  Northeast          Blue
# 141  Northeast          Blue
# ...

# %% [markdown]
# The only state west of the Mississippi that made the top 10 list from 2017-2019 was Colorado in 2018.  This potential trend would be very interesting to dive deeper into for each region of the U.S.

# %% [markdown]
# # Lowest Mean Composite Scores

# %% [markdown]
# # 2017

# %%
merge_act_census[merge_act_census['year']== '2017-01-01'].sort_values(by = 'composite').head(10)
# Out:
#              state  participation  composite       year  child_pov_rate  \
# 28          Nevada           1.00       17.8 2017-01-01           0.192
# 24     Mississippi           1.00       18.6 2017-01-01           0.276
# 40  South Carolina           1.00       18.7 2017-01-01           0.223
# 11          Hawaii           0.90       19.0 2017-01-01           0.119
# 33  North Carolina           1.00       19.1 2017-01-01           0.210
# 0          Alabama           1.00       19.2 2017-01-01           0.244
# 3         Arkansas           1.00       19.4 2017-01-01           0.225
# 36        Oklahoma           1.00       19.4 2017-01-01           0.213
# 18       Louisiana           1.00       19.5 2017-01-01           0.277
# 2          Arizona           0.62       19.7 2017-01-01           0.210
#
#    region election_2020
# 28   West          Blue
# 24  South           Red
# 40  South           Red
# 11   West          Blue
# 33  South           Red
# ...

# %% [markdown]
# # 2018

# %%
merge_act_census[merge_act_census['year']== '2018-01-01'].sort_values(by = 'composite').head(10)
# Out:
#              state  participation  composite       year  child_pov_rate  \
# 79          Nevada           1.00       17.7 2018-01-01           0.184
# 91  South Carolina           1.00       18.3 2018-01-01           0.221
# 75     Mississippi           1.00       18.6 2018-01-01           0.282
# 62          Hawaii           0.89       18.9 2018-01-01           0.118
# 51         Alabama           1.00       19.1 2018-01-01           0.239
# 84  North Carolina           1.00       19.1 2018-01-01           0.202
# 53         Arizona           0.66       19.2 2018-01-01           0.204
# 69       Louisiana           1.00       19.2 2018-01-01           0.265
# 87        Oklahoma           1.00       19.3 2018-01-01           0.214
# 54        Arkansas           1.00       19.4 2018-01-01           0.238
#
#    region election_2020
# 79   West          Blue
# 91  South           Red
# 75  South           Red
# 62   West          Blue
# 51  South           Red
# ...

# %% [markdown]
# # 2019

# %%
merge_act_census[merge_act_census['year']== '2019-01-01'].sort_values(by = 'composite').head(10)
# Out:
#               state  participation  composite       year  child_pov_rate  \
# 130          Nevada           1.00       17.9 2019-01-01           0.176
# 126     Mississippi           1.00       18.4 2019-01-01           0.276
# 142  South Carolina           0.78       18.8 2019-01-01           0.199
# 120       Louisiana           1.00       18.8 2019-01-01           0.264
# 102         Alabama           1.00       18.9 2019-01-01           0.219
# 138        Oklahoma           1.00       18.9 2019-01-01           0.197
# 104         Arizona           0.73       19.0 2019-01-01           0.192
# 135  North Carolina           1.00       19.0 2019-01-01           0.193
# 113          Hawaii           0.80       19.0 2019-01-01           0.112
# 105        Arkansas           1.00       19.3 2019-01-01           0.217
#
#     region election_2020
# 130   West          Blue
# 126  South           Red
# 142  South           Red
# 120  South           Red
# 102  South           Red
# ...

# %% [markdown]
# Many of these states have 100% participation, which may be why the scores are so low.  Think about the difference in approach a student would have if they are taking the test because they have to as opposed to because they need to score well on the ACT to get into the colleges they are interested in.  These states also hold some of the highest child poverty level in the country.

# %% [markdown]
#         - Do any states with 100% participation on the ACT have a rate change year-over-year?

# %% [markdown]
# # 100% Participation Observed in Any Year (2017-2019)

# %%
#100% participation
merge_act_census[merge_act_census['participation'] == 1]\
.pivot_table(index='state', columns= 'year')['participation']# Lowest Mean Composite Scores
# Out:
# year            2017-01-01  2018-01-01  2019-01-01
# state
# Alabama                1.0         1.0         1.0
# Arkansas               1.0         1.0         1.0
# Colorado               1.0         NaN         NaN
# Kentucky               1.0         1.0         1.0
# Louisiana              1.0         1.0         1.0
# Minnesota              1.0         NaN         NaN
# Mississippi            1.0         1.0         1.0
# Missouri               1.0         1.0         NaN
# Montana                1.0         1.0         1.0
# Nebraska               NaN         1.0         1.0
# Nevada                 1.0         1.0         1.0
# North Carolina         1.0         1.0         1.0
# Ohio                   NaN         1.0         1.0
# Oklahoma               1.0         1.0         1.0
# South Carolina         1.0         1.0         NaN
# Tennessee              1.0         1.0         1.0
# Utah                   1.0         1.0         1.0
# ...

# %% [markdown]
# Many states have adopted or moved away from mandatory ACT testing.  From what our data shows, it may indicate Colorado and Minnesota may have moved away from the ACT as a requirement after 2017.  Missouri and South Carolina may have moved away from the requirement after 2018.  Alternatively, Nebraska and Ohio may have adopted the mandate after 2017.  It could also mean that although the scores were mandated by state, certain districts may not have been able to test all students.

# %% [markdown]
#         - Do any states show >50% participation rates in the ACT each year along with a composite score above the mean?

# %% [markdown]
# # Above 50% Participation & Above $\mu$ Composite Score<br />in Each Year (2017-2019)

# %%
#greater than 50% participation with composites above mean
merge_act_census[(merge_act_census['participation'] > .5) & \
(merge_act_census['composite'] > calculate_mean(merge_act_census['composite']))]\
.pivot_table(index='state', columns='year').dropna()#drop rows that don't satisfy all filters
# Out:
#              child_pov_rate                        composite             \
# year             2017-01-01 2018-01-01 2019-01-01 2017-01-01 2018-01-01
# state
# Iowa                  0.126      0.135      0.128       21.9       21.8
# South Dakota          0.163      0.161      0.149       21.8       21.9
#
#                         participation
# year         2019-01-01    2017-01-01 2018-01-01 2019-01-01
# state
# Iowa               21.6          0.67       0.68       0.66
# South Dakota       21.6          0.80       0.77       0.75

# %%
calculate_mean(merge_act_census['child_pov_rate'])
# Out:
# 0.1694640522875817

# %% [markdown]
# It's interesting to note the only two states (Iowa & South Dakota) that had participation rates over 50% and average composite scores above the average composite scores of our datasets for all three years also had child poverty levels below the mean poverty levels for the same years.

# %% [markdown]
#         - Which colleges have the highest three year median composite ACT scores?

# %% [markdown]
# # Highest Three Year Median Composite Scores (2017-2019)

# %%
merge_act_census.pivot_table(index='state', aggfunc='median').sort_values(by= 'composite', ascending = False).head(10)
# Out:
#                child_pov_rate  composite  participation
# state
# Massachusetts           0.124       25.5           0.25
# Connecticut             0.135       25.5           0.26
# New Hampshire           0.100       25.1           0.16
# New York                0.188       24.5           0.27
# Maine                   0.142       24.3           0.07
# Rhode Island            0.180       24.2           0.15
# Michigan                0.193       24.2           0.22
# Vermont                 0.122       24.1           0.24
# Delaware                0.176       24.1           0.17
# New Jersey              0.135       23.9           0.31

# %% [markdown]
# These are all East Coast states again, but notice how low the three year median participation rates are in these states (none are above 31%).  This would reinforce our earlier observation that a high participation rates don't add up to a high average composite score, in fact it may be suggesting the opposite.

# %% [markdown]
#         - Which states have the highest and lowest three year mean ACT scores?

# %% [markdown]
# # Highest Three Year $\mu$ Composite Scores (2017-2019)

# %%
merge_act_census.pivot_table(index='state').sort_values(by= 'composite', ascending = False).head(10)
# Out:
#                child_pov_rate  composite  participation
# state
# Massachusetts        0.126333  25.466667       0.250000
# Connecticut          0.134333  25.433333       0.263333
# New Hampshire        0.094000  25.200000       0.160000
# New York             0.189667  24.400000       0.266667
# Rhode Island         0.175667  24.300000       0.160000
# Michigan             0.188000  24.233333       0.233333
# Maine                0.142667  24.200000       0.070000
# Delaware             0.172000  24.000000       0.160000
# Vermont              0.119333  23.933333       0.243333
# New Jersey           0.131667  23.933333       0.300000

# %% [markdown]
# # Lowest Three Year $\mu$ Composite Scores (2017-2019)

# %%
merge_act_census.pivot_table(index='state').sort_values(by= 'composite').head(10)
# Out:
#                 child_pov_rate  composite  participation
# state
# Nevada                0.184000  17.800000       1.000000
# Mississippi           0.278000  18.533333       1.000000
# South Carolina        0.214333  18.600000       0.926667
# Hawaii                0.116333  18.966667       0.863333
# Alabama               0.234000  19.066667       1.000000
# North Carolina        0.201667  19.066667       1.000000
# Louisiana             0.268667  19.166667       1.000000
# Oklahoma              0.208000  19.200000       1.000000
# Arizona               0.202000  19.300000       0.670000
# Arkansas              0.226667  19.366667       1.000000

# %% [markdown]
# Highest $\mu$ composite scores are all East Coast states again, but notice how much higher the childhood poverty rates are in the lowest states and take note of how many of them have participation rates of 100%!

# %% [markdown]
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
#     -This was done above at each step below the code blocks

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
#format canvas
plt.figure(figsize=(10,9))
plt.title("Correlation Between ACT Composite Scores,\nParticipation, and Childhood Poverty", fontsize = 20)

# Get correlation of variables.
corr = merge_act_census.corr()


# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
sns.heatmap(corr,
            cmap='RdYlGn',
            annot=True,
            mask = mask,
            linecolor='white',
            linewidths=.25,
            square=True,
            annot_kws={"size": 15}
           );

#format plot axes
plt.xlabel('Column from Data Set', fontsize= 15, labelpad= 20)
plt.ylabel('Column from Data Set', fontsize= 15, labelpad= 20)
plt.xticks((.5,1.5,2.5), ("Participation\nRate","Composite\nScore","Childhood Poverty Rate"), fontsize = 13)
plt.yticks((.5,1.5,2.5), ("Participation\nRate","Composite\nScore","Childhood\nPoverty Rate"), rotation = 0, fontsize = 13);


#Source: 2.01-lesson-data-viz/starter-code.ipynb

# %% [markdown]
# As we have noticed throughout the EDA, there is a significant negative correlation between between the composite scores and participation rates.  There is also a noticeable negative correlation between childhood poverty rates and composite scores, but it's not considered significant.  Lastly, there is some positive correlation between childhood poverty rates and participation rates, but it's also not considered significant.

# %% [markdown]
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %%
#format canvas
plt.figure(figsize=(16,6))

#create histogram of composite scores
sns.histplot(merge_act_census['composite'])

#format histogram
plt.title("State ACT Composite\nDistribution (2017-2019)", fontsize = 30, pad = 20)
plt.xlabel('Composite Scores', fontsize= 20, labelpad= 20)
plt.ylabel('Count', fontsize= 20, rotation= 0, labelpad= 40)
plt.axvline(x = calculate_mean(merge_act_census['composite']), color = 'red')
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13);

# %% [markdown]
# Interesting to note there are groupings slightly above the minimum and slightly below the maximum composite scores recorded.  We statistically expected to see the elevated bin on the mean, and it's understandable that more states fall below the mean since it's easier for students to do poorly on the ACT than for them to perform highly.

# %%
plt.figure(figsize=(16,6))

sns.histplot(merge_act_census['participation'])

plt.title("State ACT Participation\nDistribution (2017 - 2019)", fontsize = 30, pad = 20)
plt.xlabel('Participation Rates', fontsize= 20, labelpad= 20)
plt.ylabel('Count', fontsize= 20, rotation= 0, labelpad= 40)
plt.axvline(x = calculate_mean(merge_act_census['participation']), color = 'red')
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13);

# %% [markdown]
# Participation Rates look left skewed due to the states that have 100% participation rates in the ACT.

# %%
plt.figure(figsize=(16,6))

sns.histplot(merge_act_census['child_pov_rate'])

plt.title("State Childhood Poverty Rate\nDistribution (2017-2019)", fontsize = 30, pad = 20)
plt.xlabel('Childhood Poverty Rates', fontsize= 20, labelpad= 20)
plt.ylabel('Count', fontsize= 20, rotation= 0, labelpad= 40)
plt.axvline(x = calculate_mean(merge_act_census['child_pov_rate']), color = 'red')
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13);

# %% [markdown]
# There seems to be slightly more distribution in the childhood poverty rates above the mean.  The highest frequency of poverty rates seem to be between 12.5% and 15%.

# %% [markdown]
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels

# %%
plt.figure(figsize=(14,6))

sns.boxplot(x = merge_act_census['participation']);

plt.title("State ACT Participation Rate\nDistribution (2017-2019)", fontsize = 30, pad = 20)
plt.xlabel('Participation Rates', fontsize= 20, labelpad= 20)

plt.text(x = .25, y = -.1, s= "Q1", fontsize = 20)
plt.text(x = .065, y = -.1, s= "Min", fontsize = 20)
plt.text(x = .61, y = -.1, s= "Median", fontsize = 20)
plt.text(x = .94, y = -.15, s= "Max", fontsize = 20)
plt.text(x = .96, y = -.05, s= "Q3", fontsize = 20)
plt.xticks(fontsize = 13);

# %% [markdown]
# Participation Rates look left skewed due to the states that have 100% participation rates in the ACT.

# %%
plt.figure(figsize=(14,6))

sns.boxplot(x = merge_act_census['composite']);

plt.title("ACT Composite Score Distribution\n(2017-2019)", fontsize = 30, pad = 20)
plt.xlabel('Composite Scores', fontsize= 20, labelpad= 20)
plt.text(x= 19.9, y= -.07, s= "Q1", fontsize = 20)
plt.text(x = 17.75, y = -.07, s= "Min", fontsize = 20)
plt.text(x = 20.9, y = -.07, s= "Median", fontsize = 20)
plt.text(x = 23.2, y = -.07, s= "Q3", fontsize = 20)
plt.text(x = 24.75, y = -.07, s= "Median", fontsize = 20)
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13);

# %% [markdown]
# The composite scores seem to be tending towards normal distribution, but it's not quite there.

# %%
plt.figure(figsize=(14,6))

sns.boxplot(x = merge_act_census['child_pov_rate']);

plt.title("U.S. Childhood Poverty Rate Distribution\n(2017-2019)", fontsize = 30, pad = 20)
plt.xlabel('Youth Poverty Rates', fontsize= 20, labelpad= 20)
plt.text(x= .133, y= -.07, s= "Q1", fontsize = 20)
plt.text(x = .083, y = -.07, s= "Min", fontsize = 20)
plt.text(x = .155, y = -.07, s= "Median", fontsize = 20)
plt.text(x = .193, y = -.07, s= "Q3", fontsize = 20)
plt.text(x = .267, y = -.07, s= "Max", fontsize = 20)
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13);

# %% [markdown]
# Childhood poverty rates seem to be skewed right.  This is good, since higher poverty rates are not good.

# %% [markdown]
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable

# %%
plt.figure(figsize=(12,9))

#compare state composite score and participation by childhood poverty rate
sns.scatterplot(data= merge_act_census,
                y=merge_act_census['composite'],
                x=merge_act_census['participation'],
                hue= merge_act_census['child_pov_rate'],
                s = 200)

plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.xlabel("Participation Rate", fontsize= 20, labelpad= 20)
plt.ylabel("Composite Score", fontsize= 20, labelpad= 20)
plt.title("State's Participation Rates and Composite Scores\nBy Youth Poverty Rate (2017-2019)",
         fontsize = 20, pad = 20);
plt.legend(fontsize=13, title= 'U.S. Childhood Poverty Rate', title_fontsize = 15, markerscale= 2);

# %% [markdown]
# There seems to be a trend that given any participation rate, the states with higher poverty rates get lower composite scores.  This trend seems to be most predominant in the states with 100% participation rates.

# %% [markdown]
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
plt.figure(figsize=(12,9))

#compare composite and participation by us census region
sns.scatterplot(data= merge_act_census,
                y=merge_act_census['composite'],
                x=merge_act_census['participation'],
                hue= merge_act_census['region'],
                s = 150,
                style=merge_act_census['region']) #set markers based on state

plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.xlabel("Participation Rate", fontsize= 20, labelpad= 20)
plt.ylabel("Composite Score", fontsize= 20, labelpad= 20)
plt.title("State's Participation Rates and Composite Scores\nBy U.S. Census Regions (2017-2019)",
         fontsize = 20, pad = 20);
plt.legend(fontsize=15, title= 'U.S. Census Region', title_fontsize = 20, markerscale= 2);

# %% [markdown]
# States in the Northeast seem to excel in the average composite scores, but they don't have high participation rates.  It seems to be the exact opposite for states in the south.  States in the Midwest seem to have the high participation rates and composite scores.  This trend seems to apply to states in the West, too, but they also seem to have a grouping with higher participation rates and lower composite scores.

# %%
plt.figure(figsize=(12,9))

#compare composite and participation by us 2020 election results
sns.scatterplot(data= merge_act_census,
                y=merge_act_census['composite'],
                x=merge_act_census['participation'],
                hue= merge_act_census['election_2020'],
                s = 150,
                style=merge_act_census['election_2020'], #set markers to election results
                palette= ['red','blue']) #make red appear red and blue appear blue

plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.xlabel("Participation Rate", fontsize= 20, labelpad= 20)
plt.ylabel("Composite Score", fontsize= 20, labelpad= 20)
plt.title("State's ACT Participation Rates and Composite Scores\nBy 2020 Presidential Election Results (2017-2019)",
         fontsize = 20, pad = 20);
plt.legend(fontsize=13, title= '2020 Presidential\nElection Results', title_fontsize = 15, markerscale= 2);

# %% [markdown]
# States with the highest composite scores went blue in the 2020 Presidential Election.  Also note the state with the lowest composite scores also went blue (Nevada).  The states that went red had the highest frequency of 100% participation rates, but the states that had the highest composite scores with 100% participation went blue.  There is a solid group of red states that had greater than 60% participation and a composite score above 20.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# There is a significant negative correlation between a state's participation rate and their composite score.  If time and money are being allocated in mandating students to take the ACT, states should move away from mandatory testing and divert those resources into community programs designed to combat childhood poverty.  The participation rates for those states will absolutely take a hit, but due to the negative correlation it should help raise the composite scores.
#
# In order to find out the best ways to do this this, we should take a look at the ACT policies of the states in Northeast and explore their policies and procedures.  It also looks like the majority of states that require mandatory ACT testing tended to vote Republican in the 2020 presidential election.  These states should look at the policies of the other states that voted Republican in 2020 but had participation above 60% and composite scores above 21, particularly Iowa and South Dakota.  That way they can still prioritize participation rates but raise how well the students are doing on the ACT which is ultimately what matters.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
